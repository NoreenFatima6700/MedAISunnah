# %% [markdown]
# <a href="https://colab.research.google.com/github/NoreenFatima6700/MedAISunnah/blob/main/MedAISunnah_RAG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sentence-transformers faiss-cpu transformers torch pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 91.7 MB/s eta 0:00:00
# ...

# %%
from src.qa_pipeline import MedAISunnahQA

qa = MedAISunnahQA()
result = qa.answer("What does Islam say about honey as medicine?")
print(result["answer"])
print("Sources:", result["citations"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1151557390.py in <cell line: 0>()
# ----> 1 from src.qa_pipeline import MedAISunnahQA
#       2
#       3 qa = MedAISunnahQA()
#       4 result = qa.answer("What does Islam say about honey as medicine?")
#       5 print(result["answer"])
#
# ModuleNotFoundError: No module named 'src'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
